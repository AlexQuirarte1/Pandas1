# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\aquirart\Desktop\Inactive_Term YE OVP Cases December 2023_Created.csv")
df
# Out:
#                      Id  Success  Created  Case Number       Employee SFID  \
# 0    5008a00002MdBsSAAV     True     True      1795667  0033l00002WLGBoAAP
# 1    5008a00002MdBtBAAV     True     True      1795672  0033l00002YhzTpAAJ
# 2    5008a00002MdBtCAAV     True     True      1795673  0033l00002Kn4fWAAR
# 3    5008a00002MdBtDAAV     True     True      1795674  0033l00002WLAsnAAH
# 4    5008a00002MdBtEAAV     True     True      1795675  0031N00001dAyV5QAK
# ..                  ...      ...      ...          ...                 ...
# 168  5008a00002MdBwCAAV     True     True      1795843  0033l00002WLFWxAAP
# 169  5008a00002MdBwDAAV     True     True      1795844  0033l00002tlcVuAAI
# 170  5008a00002MdBwEAAV     True     True      1795845  0033l000030CIVNAA4
# 171  5008a00002MdBwFAAV     True     True      1795846  0033l00002P6oucAAB
# 172  5008a00002MdBwGAAV     True     True      1795847  0033l000030xRejAAE
#
# ...

# %%
pd.set_option('display.max.rows',500)

# %%
df[df['Business Unit'] == 'IRCMP']
# Out:
#                      Id  Success  Created  Case Number       Employee SFID  \
# 159  5008a00002MdBw3AAF     True     True      1795833  0038a00003PIqb6AAD
# 160  5008a00002MdBw4AAF     True     True      1795834  0033l00002P4KCaAAN
# 161  5008a00002MdBw5AAF     True     True      1795835  0033l00002P4jOzAAJ
# 162  5008a00002MdBw6AAF     True     True      1795836  0033l000037n9TpAAI
# 163  5008a00002MdBw7AAF     True     True      1795837  0033l00002P4iSPAAZ
# 164  5008a00002MdBw8AAF     True     True      1795838  0033l00002P4iaNAAR
# 165  5008a00002MdBw9AAF     True     True      1795839  0033l00002P4K68AAF
# 166  5008a00002MdBwAAAV     True     True      1795841  0033l00002P4MAdAAN
# 167  5008a00002MdBwBAAV     True     True      1795842  0033l00002P4KuYAAV
# 168  5008a00002MdBwCAAV     True     True      1795843  0033l00002WLFWxAAP
# 169  5008a00002MdBwDAAV     True     True      1795844  0033l00002tlcVuAAI
# ...

# %%
specific_business_units = ['IRCMP','IRMED']

df[df['Business Unit'].isin(specific_business_units)]
# Out:
#                      Id  Success  Created  Case Number       Employee SFID  \
# 159  5008a00002MdBw3AAF     True     True      1795833  0038a00003PIqb6AAD
# 160  5008a00002MdBw4AAF     True     True      1795834  0033l00002P4KCaAAN
# 161  5008a00002MdBw5AAF     True     True      1795835  0033l00002P4jOzAAJ
# 162  5008a00002MdBw6AAF     True     True      1795836  0033l000037n9TpAAI
# 163  5008a00002MdBw7AAF     True     True      1795837  0033l00002P4iSPAAZ
# 164  5008a00002MdBw8AAF     True     True      1795838  0033l00002P4iaNAAR
# 165  5008a00002MdBw9AAF     True     True      1795839  0033l00002P4K68AAF
# 166  5008a00002MdBwAAAV     True     True      1795841  0033l00002P4MAdAAN
# 167  5008a00002MdBwBAAV     True     True      1795842  0033l00002P4KuYAAV
# 168  5008a00002MdBwCAAV     True     True      1795843  0033l00002WLFWxAAP
# 169  5008a00002MdBwDAAV     True     True      1795844  0033l00002tlcVuAAI
# ...

# %%
df[df['Business Unit'].str.contains('IRMED')]
# Out:
#                      Id  Success  Created  Case Number       Employee SFID  \
# 171  5008a00002MdBwFAAV     True     True      1795846  0033l00002P6oucAAB
# 172  5008a00002MdBwGAAV     True     True      1795847  0033l000030xRejAAE
#
#       Empl ID Business Unit  Do Not Notify  Validated  Submitter Name  ...  \
# 171  10314409         IRMED           True       True             NaN  ...
# 172  10576463         IRMED           True       True             NaN  ...
#
#                   Subject                                        Description  \
# 171  Overpayment Recovery  Employee has an active overpayment, communicat...
# 172  Overpayment Recovery  Employee has an active overpayment, communicat...
#
#     Account Id     Case Owner            Owner Id      Case Origin  \
# 171        NaN  Annette Dwyer  0051N00000952AFQAY  UCPC PeopleSoft
# 172        NaN  Annette Dwyer  0051N00000952AFQAY  UCPC PeopleSoft
#
#       Requested By    Topic              Category  \
# ...

# %%
group_by_frame = df.groupby('Business Unit')

# %%
group_by_frame.count()
# Out:
#                 Id  Success  Created  Case Number  Employee SFID  Empl ID  \
# Business Unit
# IRCMP           12       12       12           12             12       12
# IRMED            2        2        2            2              2        2
# SFCMP          155      155      155          155            155      155
# SFMED            4        4        4            4              4        4
#
#                Do Not Notify  Validated  Submitter Name  Submitter Emplid  \
# Business Unit
# IRCMP                     12         12               0                 0
# IRMED                      2          2               0                 0
# SFCMP                    155        155               0                 0
# SFMED                      4          4               0                 0
#
#                ...  Subject  Description  Account Id  Case Owner  Owner Id  \
# Business Unit  ...
# IRCMP          ...       12           12           0          12        12
# ...

# %%
df.groupby('Business Unit').min()
# Out:
#                                Id  Success  Created  Case Number  \
# Business Unit
# IRCMP          5008a00002MdBw3AAF     True     True      1795833
# IRMED          5008a00002MdBwFAAV     True     True      1795846
# SFCMP          5008a00002MdBeNAAV     True     True      1795667
# SFMED          5008a00002MdBtcAAF     True     True      1795695
#
#                     Employee SFID   Empl ID  Do Not Notify  Validated  \
# Business Unit
# IRCMP          0033l00002P4K68AAF  10278928           True       True
# IRMED          0033l00002P6oucAAB  10314409           True       True
# SFCMP          0031N00001dAyV5QAK  10031810           True       True
# SFMED          0033l00002Yhzd3AAB  10378857           True       True
#
#                Submitter Name  Submitter Emplid  ...  \
# Business Unit                                    ...
# IRCMP                     NaN               NaN  ...
# IRMED                     NaN               NaN  ...
# ...

# %%
df.groupby('Business Unit').max()
# Out:
#                                Id  Success  Created  Case Number  \
# Business Unit
# IRCMP          5008a00002MdBwEAAV     True     True      1795845
# IRMED          5008a00002MdBwGAAV     True     True      1795847
# SFCMP          5008a00002MdBw2AAF     True     True      1795832
# SFMED          5008a00002MdBvOAAV     True     True      1795797
#
#                     Employee SFID   Empl ID  Do Not Notify  Validated  \
# Business Unit
# IRCMP          0038a00003PIqb6AAD  10694761           True       True
# IRMED          0033l000030xRejAAE  10576463           True       True
# SFCMP          0038a00003LRMl3AAH  10668539           True       True
# SFMED          0033l00002abEkmAAE  10433521           True       True
#
#                Submitter Name  Submitter Emplid  ...  \
# Business Unit                                    ...
# IRCMP                     NaN               NaN  ...
# IRMED                     NaN               NaN  ...
# ...

# %%
df.groupby('Business Unit').agg({'Created' : ['count', 'sum']})
# Out:
#               Created
#                 count  sum
# Business Unit
# IRCMP              12   12
# IRMED               2    2
# SFCMP             155  155
# SFMED               4    4

# %%
df.groupby(['Business Unit','Subcategory']).agg({'Id' : ['count']})
# Out:
#                                                    Id
#                                                 count
# Business Unit Subcategory
# IRCMP         Overpayment Elections/Submissions    12
# IRMED         Overpayment Elections/Submissions     2
# SFCMP         Overpayment Elections/Submissions   155
# SFMED         Overpayment Elections/Submissions     4

# %%
import duckdb

# %%
duckdb.sql('SELECT 42').show()
# Out:
# ┌───────┐
# │  42   │
# │ int32 │
# ├───────┤
# │    42 │
# └───────┘

# %%
# create a connection to a file called 'file.db'
con = duckdb.connect('file.db')
# create a table and load data into it
con.sql('INSERT INTO test VALUES (42)')
con.sql('INSERT INTO test VALUES (43)')
con.sql('INSERT INTO test VALUES (44)')
# query the table
con.table('test').show()
con.close()
# Out:
# ┌───────┐
# │   i   │
# │ int32 │
# ├───────┤
# │    42 │
# │    42 │
# │    43 │
# │    44 │
# │    42 │
# │    43 │
# │    44 │
# └───────┘
