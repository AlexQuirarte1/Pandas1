# %% [markdown]
# #Import Pands

# %%
import pandas as pd
import glob

# %% [markdown]
# #Read from CSV

# %%
df1 = pd.read_csv(r"C:\Users\aquirart\Desktop\1st ACA Program - SMP-ACA LOSS-BW MSM.csv")
df2 = pd.read_csv(r"C:\Users\aquirart\Desktop\2nd ACA Program - SMP-ACA LOSS-BW MSM.csv")

# %%
file_name = glob.glob(r"C:\Users\aquirart\Desktop\1st ACA Program - SMP-ACA LOSS-BW MSM.csv")
df1['file_name'] = file_name
print(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 2
#       1 file_name = glob.glob(r"C:\Users\aquirart\Desktop\1st ACA Program - SMP-ACA LOSS-BW MSM.csv")
# ----> 2 df1['file_name'] = file_name
#       3 print(df)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:4094, in DataFrame.__setitem__(self, key, value)
#    4091     self._setitem_array([key], value)
#    4092 else:
#    4093     # set column
# -> 4094     self._set_item(key, value)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:4303, in DataFrame._set_item(self, key, value)
#    4293 def _set_item(self, key, value) -> None:
#    4294     """
# ...

# %%
df1.insert()
# Out:
#       Prospect Id First Name       Last Name                      Email  \
# 0        64816381   Qianqian              Su             xpsqq@ucla.edu
# 1        63483991     Sheryl          Ocampo        sherylo473@ucla.edu
# 2        63484007    Rithwik          Pandey           rithwik@ucla.edu
# 3        63484051      Mirna          Kassem  kassem_mirna@berkeley.edu
# 4        63484129    Yoojung             Kim        yoojungkim@ucla.edu
# ...           ...        ...             ...                        ...
# 2561     75853099    William           Evans        wrevans@ucdavis.edu
# 2562     76595418  Prashanth          Gaddam  prashanth.gaddam@ucop.edu
# 2563     64302925    Vanessa           Jasso     vanessa.jasso@ucop.edu
# 2564     76467719    Shannon  Hemming-Flower   shannon.hemming@ucop.edu
# 2565     66181555    Devansh         Agarwal         d1agarwal@ucsd.edu
#
#                      Company  Last Activity At  \
# 0                UCLA Campus               NaN
# ...

# %%
df2
# Out:
#       Prospect Id First Name       Last Name                      Email  \
# 0        63483991     Sheryl          Ocampo        sherylo473@ucla.edu
# 1        63484007    Rithwik          Pandey           rithwik@ucla.edu
# 2        63484051      Mirna          Kassem  kassem_mirna@berkeley.edu
# 3        63484129    Yoojung             Kim        yoojungkim@ucla.edu
# 4        63484201       Yang              Ni               yni3@uci.edu
# ...           ...        ...             ...                        ...
# 1909     72549975   Nickolas             Chu         nclchu@ucdavis.edu
# 1910     72550677  Raphaella       Banholzer     rbanholzer@ucdavis.edu
# 1911     72555129    Tzu Hua              Ho          oliho@ucdavis.edu
# 1912     75843016      Nghia            Pham            nghiacp@uci.edu
# 1913     76467719    Shannon  Hemming-Flower   shannon.hemming@ucop.edu
#
#                      Company     Last Activity At  \
# 0                UCLA Campus                  NaN
# ...

# %%
df1.merge(df2,how= 'left', on = 'Prospect Id')
# Out:
#       Prospect Id First Name_x     Last Name_x                    Email_x  \
# 0        64816381     Qianqian              Su             xpsqq@ucla.edu
# 1        63483991       Sheryl          Ocampo        sherylo473@ucla.edu
# 2        63484007      Rithwik          Pandey           rithwik@ucla.edu
# 3        63484051        Mirna          Kassem  kassem_mirna@berkeley.edu
# 4        63484129      Yoojung             Kim        yoojungkim@ucla.edu
# ...           ...          ...             ...                        ...
# 2561     75853099      William           Evans        wrevans@ucdavis.edu
# 2562     76595418    Prashanth          Gaddam  prashanth.gaddam@ucop.edu
# 2563     64302925      Vanessa           Jasso     vanessa.jasso@ucop.edu
# 2564     76467719      Shannon  Hemming-Flower   shannon.hemming@ucop.edu
# 2565     66181555      Devansh         Agarwal         d1agarwal@ucsd.edu
#
#                    Company_x Last Activity At_x  \
# ...
